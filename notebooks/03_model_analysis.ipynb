# %% [markdown]
# # 03 — Model analysis
# Read persisted expanding-window results and ablations.

# %%
from dashboard.data import default_database_url, load_model_performance
from src.database.engine import Database

database_url = default_database_url()
Database.from_url(database_url).initialize()
performance = load_model_performance(database_url)
performance

# %%
performance.sort_values("mae").head(10) if not performance.empty else performance
